# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\rahul\OneDrive\Documents\shopping_behavior.csv")

# %%
df.head(3)
# Out:
#    Customer ID                                                                                                                                                                                                                                                                                                     \
# 0                                                  1
# 1                                                  2
# 2                                                  3
#
#    Age Gender Item Purchased  Category  Purchase Amount (USD)       Location  \
# 0   55   Male         Blouse  Clothing                     53       Kentucky
# 1   19   Male        Sweater  Clothing                     64          Maine
# 2   50   Male          Jeans  Clothing                     73  Massachusetts
#
#   Size   Color  Season  Review Rating Subscription Status  Shipping Type  \
# 0    L    Gray  Winter            3.1                 Yes        Express
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 18 columns):
#  #   Column                                                                                                                                                                                                                                                                                                          Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                                                                                                                          --------------  -----
# ...

# %%
df.describe(include="all")
# Out:
#         Customer ID                                                                                                                                                                                                                                                                                                     \
# count                                         3900.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                          1950.500000
# std                                           1125.977353
# min                                              1.000000
# 25%                                            975.750000
# 50%                                           1950.500000
# 75%                                           2925.250000
# max                                           3900.000000
#
# ...

# %%
df['Review Rating'] = df.groupby('Category')['Review Rating'].transform(lambda x:x.fillna(x.median()))
df.isnull().sum()
# Out:
# Customer ID                                                                                                                                                                                                                                                                                                       0
# Age                                                                                                                                                                                                                                                                                                               0
# Gender                                                                                                                                                                                                                                                                                                            0
# ...

# %%
df.columns
# Out:
# Index(['Customer ID                                                                                                                                                                                                                                                                                                   ',
#        'Age', 'Gender', 'Item Purchased', 'Category', 'Purchase Amount (USD)',
#        'Location', 'Size', 'Color', 'Season', 'Review Rating',
#        'Subscription Status', 'Shipping Type', 'Discount Applied',
#        'Promo Code Used', 'Previous Purchases', 'Payment Method',
#        'Frequency of Purchases'],
#       dtype='object')

# %%
df.columns = df.columns.str.lower()
df.columns = df.columns.str.replace(' ','_')

# %%
df.columns
# Out:
# Index(['customer_id___________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________',
#        'age', 'gender', 'item_purchased', 'category', 'purchase_amount_(usd)',
#        'location', 'size', 'color', 'season', 'review_rating',
#        'subscription_status', 'shipping_type', 'discount_applied',
#        'promo_code_used', 'previous_purchases', 'payment_method',
#        'frequency_of_purchases'],
#       dtype='object')

# %%
df = df.rename(columns = {'purchase_amount_(usd)' : 'purchase_amount'})

# %%
df.columns
# Out:
# Index(['customer_id___________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________',
#        'age', 'gender', 'item_purchased', 'category', 'purchase_amount',
#        'location', 'size', 'color', 'season', 'review_rating',
#        'subscription_status', 'shipping_type', 'discount_applied',
#        'promo_code_used', 'previous_purchases', 'payment_method',
#        'frequency_of_purchases'],
#       dtype='object')

# %%
#create a column age_group
labels = ['Young Adult','Adult','Middle-aged','Senior']
df['age_group'] = pd.qcut(df['age'],  q=4,labels = labels)

# %%
df[['age','age_group']].head(5)
# Out:
#    age    age_group
# 0   55  Middle-aged
# 1   19  Young Adult
# 2   50  Middle-aged
# 3   21  Young Adult
# 4   45  Middle-aged

# %%
#create a column purchase_frequency_days
frequency_mapping = {
    'Fortnightly':14,
    'Weekly':7,
    'Monthly' :30,
    'Quarterly':90,
    'Bi-Weekly':14,
    'Annually':365,
    'Every 3 Months':90
}
df['purchase_frequency_days'] = df['frequency_of_purchases'].map(frequency_mapping)

# %%
df[['purchase_frequency_days', 'frequency_of_purchases']].head(5)
# Out:
#    purchase_frequency_days frequency_of_purchases
# 0                       14            Fortnightly
# 1                       14            Fortnightly
# 2                        7                 Weekly
# 3                        7                 Weekly
# 4                      365               Annually

# %%
df[['discount_applied','promo_code_used']].head(5)
# Out:
#   discount_applied promo_code_used
# 0              Yes             Yes
# 1              Yes             Yes
# 2              Yes             Yes
# 3              Yes             Yes
# 4              Yes             Yes

# %%
df = df.drop('promo_code_used',axis=1)

# %%
df.columns
# Out:
# Index(['customer_id___________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________________',
#        'age', 'gender', 'item_purchased', 'category', 'purchase_amount',
#        'location', 'size', 'color', 'season', 'review_rating',
#        'subscription_status', 'shipping_type', 'discount_applied',
#        'previous_purchases', 'payment_method', 'frequency_of_purchases',
#        'age_group', 'purchase_frequency_days'],
#       dtype='object')

# %%
pip install sqlalchemy pymysql
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install pymysql sqlalchemy

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
username = "root"
password = "1111"
host = "localhost"
port = "3306"
database = "customer_behaviour"

engine = create_engine(
    f"mysql+pymysql://{username}:{password}@{host}:{port}/{database}")

# %%
connection = engine.connect()
print("Connected Successfully")
connection.close()
# Out:
# Connected Successfully

# %%
df = pd.read_sql("SELECT * FROM customer1", engine)
df.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %%
df = pd.read_csv(r"C:\Users\rahul\Downloads\customer_shopping_behavior.csv")

df.to_sql(
    name="customer1",
    con=engine,
    if_exists="replace",
    index=False
)

print("Data Uploaded Successfully")

# %%
! pip install mysql-connector-python

# %%
import mysql.connector as sql

# %%
conn = mysql.connector.connect(
    host = "localhost",
    user = "root",
    password = "1111",
    database = "customer_behaviour")
mycursor = conn.cursor()
print(conn)

# %%
mycursor.execute("select * from customer1")
output = mycursor.fetchall()

for x in output:
    print(x)
